# %%
num=int(input("Enter a number:"))
factorial = 1
for i in range(1, num + 1):
  factorial *= 1
  print("Factorial =", factorial)
# Out:
# Enter a number:4
# Factorial = 1
# Factorial = 1
# Factorial = 1
# Factorial = 1

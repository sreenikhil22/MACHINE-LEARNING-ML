# %%
a=float(input('Enter the length'))
b=float(input('Enter the height'))
area = b * a
print('The area of rectangle is = ' ,area)
# Out:
# Enter the length68
# Enter the height69
# The area of rectangle is =  4692.0
